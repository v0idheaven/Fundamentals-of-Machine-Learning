# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Creating a DataFrame

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ['Name', 'Age', 'City', 'Salary']
df2 = pd.DataFrame(data_list, columns=columns)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# #### Selection and indexing of column

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: str

# %%
df2[["Name", "City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# #### Creating a new column

# %%
df2["Designation"] = ["Engineer", "Manager", "Analyst", "Director"]

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000    Engineer
# 1   Anna   34     Paris   70000     Manager
# 2  Peter   29    Berlin   62000     Analyst
# 3  Linda   42    London   85000    Director

# %%
df2.drop("City", axis=1)
# Use implace=True to make the changes permanent
# Out:
#     Name  Age  Salary Designation
# 0   John   28   65000    Engineer
# 1   Anna   34   70000     Manager
# 2  Peter   29   62000     Analyst
# 3  Linda   42   85000    Director

# %%
df2.drop(0, axis=0)
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000     Manager
# 2  Peter   29  Berlin   62000     Analyst
# 3  Linda   42  London   85000    Director

# %% [markdown]
# #### Selecting Rows

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000    Engineer
# 1   Anna   34     Paris   70000     Manager
# 2  Peter   29    Berlin   62000     Analyst
# 3  Linda   42    London   85000    Director

# %%
df2.loc[0]
# Out:
# Name               John
# Age                  28
# City           New York
# Salary            65000
# Designation    Engineer
# Name: 0, dtype: object

# %%
df2.loc[[0, 1]]
# Out:
#    Name  Age      City  Salary Designation
# 0  John   28  New York   65000    Engineer
# 1  Anna   34     Paris   70000     Manager

# %%
df2.iloc[3]
# Out:
# Name              Linda
# Age                  42
# City             London
# Salary            85000
# Designation    Director
# Name: 3, dtype: object

# %% [markdown]
# ##### Selecting Subsets of Rows and Columns

# %%
df.loc[[0, 1]][['City', 'Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.iloc[[2,3]][['Name', 'Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# ##### Conditional Selection

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000    Engineer
# 1   Anna   34     Paris   70000     Manager
# 2  Peter   29    Berlin   62000     Analyst
# 3  Linda   42    London   85000    Director

# %%
# I only want to see those people who are older than 30 years

# %%
df2[df2['Age'] > 30]
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000     Manager
# 3  Linda   42  London   85000    Director

# %%
# I only want people who are older than 30 years and there city must be London

# %%
df2[(df2['Age'] > 30) & (df2['City'] == 'London')]
# Out:
#     Name  Age    City  Salary Designation
# 3  Linda   42  London   85000    Director
